# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader, random_split
from pathlib import Path
import matplotlib.pyplot as plt


data_root = Path("/workspace/Projekt/Testdaten/Data/SAP Bilder sortiert")

transform_train = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

transform_val = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])


full_data = datasets.ImageFolder(
    root=data_root,
    transform=transform_train,
    is_valid_file=lambda path: ".ipynb_checkpoints" not in path
)

# Split: 80% Training, 20% Validation
val_size = int(0.2 * len(full_data))
train_size = len(full_data) - val_size
train_data, val_data = random_split(full_data, [train_size, val_size])

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_data, batch_size=32, shuffle=False)

num_classes = len(full_data.classes)
print("Klassen:", full_data.classes)


model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)



# Class Weights berechnen (png, jpg, jpeg)
class_counts = torch.tensor([
    len(list((data_root/class_name).glob("*.png"))) +
    len(list((data_root/class_name).glob("*.jpg"))) +
    len(list((data_root/class_name).glob("*.jpeg")))
    for class_name in full_data.classes
], dtype=torch.float)

weights = 1.0 / class_counts
weights = weights / weights.sum() * len(weights)

criterion = nn.CrossEntropyLoss(weight=weights.to(device))


criterion = nn.CrossEntropyLoss(weight=weights.to(device))

optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)


epochs = 20
train_losses, val_losses = [], []
best_val_acc = 0.0

Path("outputs").mkdir(exist_ok=True)

for epoch in range(epochs):
    # Training
    model.train()
    running_loss, correct, total = 0.0, 0, 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_acc = correct / total
    train_losses.append(running_loss/len(train_loader))

    # Validation
    model.eval()
    val_loss, val_correct, val_total = 0.0, 0, 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            val_correct += (preds == labels).sum().item()
            val_total += labels.size(0)

    val_acc = val_correct / val_total
    val_losses.append(val_loss/len(val_loader))

    print(f"Epoch {epoch+1}/{epochs} | "
          f"Train Loss: {train_losses[-1]:.4f}, Acc: {train_acc:.4f} | "
          f"Val Loss: {val_losses[-1]:.4f}, Acc: {val_acc:.4f}")

    # Bestes Modell speichern
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "outputs/resnet_best01.pt")
        print(f"✅ Bestes Modell gespeichert (Epoche {epoch+1}, Val-Acc: {val_acc:.4f})")
    scheduler.step()



plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Training & Validation Loss")
plt.show()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/mambauser/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# Klassen: ['ABAP Dictionary', 'BW4Cockpit (Stammdaten)', 'Bewegungsdaten', 'Composite Provider', 'DTP', 'Data Flow Object', 'Data Mart', 'Data Source', 'Data Store Object', 'Datenvorschau', 'Excel', 'Query', 'Transformationen']
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 109MB/s]
# Epoch 1/20 | Train Loss: 1.8747, Acc: 0.4315 | Val Loss: 7.9765, Acc: 0.4000
# ✅ Bestes Modell gespeichert (Epoche 1, Val-Acc: 0.4000)
# Epoch 2/20 | Train Loss: 1.0095, Acc: 0.7114 | Val Loss: 3.9684, Acc: 0.3059
# Epoch 3/20 | Train Loss: 0.6690, Acc: 0.8426 | Val Loss: 1.5486, Acc: 0.7765
# ✅ Bestes Modell gespeichert (Epoche 3, Val-Acc: 0.7765)
# Epoch 4/20 | Train Loss: 0.5297, Acc: 0.8717 | Val Loss: 1.8109, Acc: 0.6000
# Epoch 5/20 | Train Loss: 0.3428, Acc: 0.8892 | Val Loss: 0.7538, Acc: 0.7882
# ✅ Bestes Modell gespeichert (Epoche 5, Val-Acc: 0.7882)
# ...
